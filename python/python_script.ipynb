# %%
import best_time
best_time.box_plots_best_time()

# %%
import older_planes
older_planes.box_plot_decade_planes()

# %%
import number_of_flights_change
number_of_flights_change.networks_popular_flights()

# %%
import cascade_delay
origin, delayed = cascade_delay.tables_delayed_cascade_delays()

# %%
origin
# Out:
#    Year  Month  DayOfMonth  CRSDepTime  DepTime  DepDelay  CRSArrTime  \
# 0  2007     12          27        1130   1207.0      37.0        1330
#
#    ArrTime  ArrDelay Origin Dest  FlightNum
# 0   1404.0      34.0    CHS  DFW       3474

# %%
delayed
# Out:
#     Year  Month  DayOfMonth  CRSDepTime  DepTime  DepDelay  CRSArrTime  \
# 0   2007     12          27        1355   1458.0      63.0        1745
# 1   2007     12          27        1335   1437.0      62.0        1745
# 2   2007     12          27        1400   1458.0      58.0        1505
# 3   2007     12          27        1335   1427.0      52.0        1445
# 4   2007     12          27        1400   1447.0      47.0        1515
# 5   2007     12          27        1355   1436.0      41.0        1730
# 6   2007     12          27        1400   1440.0      40.0        1545
# 7   2007     12          27        1355   1430.0      35.0        1715
# 8   2007     12          27        1340   1413.0      33.0        1500
# 9   2007     12          27        1400   1427.0      27.0        1520
# 10  2007     12          27        1400   1427.0      27.0        1619
# 11  2007     12          27        1345   1408.0      23.0        1445
# ...

# %%
import ml_model
model, score = ml_model.logreg_classif_plot_coef()
print(score)
# Out:
# 0.5993748599426214
